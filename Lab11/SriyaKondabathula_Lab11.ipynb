# %% [markdown]
# ## More about clustering....

# %% [markdown]
# ###Problem 1###
# There are many other clustering algorithms implemented in the scikit learn library. Let's dive into them one by one.

# %%
# First, let's take a look at the blob data. Here we make use of sklearn.datasets.make_blobs.

############## Given code ##############
from sklearn.datasets import make_blobs
X,y = make_blobs(n_samples=100, n_features=2, random_state=1, centers=3)
########################################

# Create a scatterplot from the data X with different colors according to y values. 
# There should be three different clusters.

########## Your answer here ############
import matplotlib.pyplot as plt
plt.figure()
colors_list = ['r', 'g', 'b']
for i in range(3):
  plt.scatter(X[y == i][:, 0], X[y == i][:, 1], c = colors_list[i])
########################################

# %% [markdown]
# ###Problem 2
#
# Now, let's apply different clustering algorithms.

# %%
# Let's use different modules from sklearn.cluster and visualize your clusters.
# Here we are using KMeans. You will need to use this to predict and plot the data using a scatter plot. 

############## Given code ##############
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=3, random_state=42)
########################################

########## Your answer here ############
kmeans.fit(X)
y_kmeans = kmeans.predict(X)

plt.figure()
for i in range(3):
  plt.scatter(X[y_kmeans == i][:, 0], X[y_kmeans == i][:, 1], c = colors_list[i])
########################################
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
# Here we are using SpectralClustering. You will need to use this to predict and plot the data using a scatter plot. 

############## Given code ##############
from sklearn.cluster import SpectralClustering
spec = SpectralClustering(n_clusters=3)
########################################

########## Your answer here ############
y_spec = spec.fit_predict(X)

plt.figure()
for i in range(3):
  plt.scatter(X[y_kmeans == i][:, 0], X[y_kmeans == i][:, 1], c = colors_list[i])
########################################

# %%
# Here we are using GaussianMixture. You will need to use this to predict and plot the data using a scatter plot. 

############## Given code ##############
from sklearn.mixture import GaussianMixture
GM = GaussianMixture(n_components=3, random_state=42)
########################################

########## Your answer here ############
y_gm = GM.fit_predict(X)

plt.figure()
for i in range(3):
  plt.scatter(X[y_gm == i][:, 0], X[y_gm == i][:, 1], c = colors_list[i])
########################################

# %%
# Here we are using OPTICS. You will need to use this to predict and plot the data using a scatter plot. 

############## Given code ##############
from sklearn.cluster import OPTICS
optics = OPTICS(min_samples=20)
########################################

########## Your answer here ############
y_optics = optics.fit_predict(X)

plt.figure()
for i in range(3):
  plt.scatter(X[y_optics == i][:, 0], X[y_optics == i][:, 1], c = colors_list[i])
########################################

# %% [markdown]
# ###Problem 3
#
# Let's try different datasets and reapply all these different clustering methods including KMeans, SpectralClustering, GaussianMixture, and OPTICS.

# %%
# We are going to use a different data set to see how the clustering works with this new data. 
# Take a look at this link to understand what the output will look like. 
# https://scikit-learn.org/stable/modules/generated/sklearn.datasets.make_circles.html
# Do similar to what you did above in Problem 2 for each part. 

############## Given code ##############
from sklearn import datasets
X,y = datasets.make_circles(200)
colors_list2 = ['r', 'g']
########################################


########## Your answer here ############
# KMeans...
kmeans = KMeans(n_clusters = 2, random_state = 42)

kmeans.fit(X)
y_kmeans = kmeans.predict(X)

plt.figure()
plt.title('K-Means')
for i in range(2):
  plt.scatter(X[y_kmeans == i][:, 0], X[y_kmeans == i][:, 1], c = colors_list2[i])
########################################


########## Your answer here ############
# SpectralClustering... 
spec = SpectralClustering(n_clusters = 2)

y_spec = spec.fit_predict(X)

plt.figure()
plt.title('Spectral Clustering')
for i in range(2):
  plt.scatter(X[y_spec == i][:, 0], X[y_spec == i][:, 1], c = colors_list2[i])
########################################


########## Your answer here ############
# GaussianMixture...
GM = GaussianMixture(n_components = 2, random_state = 42)

y_gm = GM.fit_predict(X)

plt.figure()
plt.title('Gaussian Mixture')
for i in range(2):
  plt.scatter(X[y_gm == i][:, 0], X[y_gm == i][:, 1], c = colors_list2[i])
########################################

########## Your answer here ############
# OPTICS...
optics = OPTICS(min_samples = 5)

y_optics = optics.fit_predict(X)

plt.figure()
plt.title('OPTICS')
for i in range(2):
  plt.scatter(X[y_optics == i][:, 0], X[y_optics == i][:, 1], c = colors_list2[i])
########################################
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
# Now, try another different dataset and reapply all these different clustering methods.
# Here we are using https://scikit-learn.org/stable/modules/generated/sklearn.datasets.make_moons.html.

############## Given code ##############
from sklearn import datasets
X,y = datasets.make_moons(200)
########################################

########## Your answer here ############
# KMeans...
kmeans = KMeans(n_clusters = 2, random_state = 42)

kmeans.fit(X)
y_kmeans = kmeans.predict(X)

plt.figure()
plt.title('K-Means')
for i in range(2):
  plt.scatter(X[y_kmeans == i][:, 0], X[y_kmeans == i][:, 1], c = colors_list2[i])
########################################


########## Your answer here ############
# SpectralClustering... 
spec = SpectralClustering(n_clusters = 2)

y_spec = spec.fit_predict(X)

plt.figure()
plt.title('Spectral Clustering')
for i in range(2):
  plt.scatter(X[y_spec== i][:, 0], X[y_spec == i][:, 1], c = colors_list2[i])
########################################


########## Your answer here ############
# GaussianMixture...
GM = GaussianMixture(n_components = 2, random_state = 42)

y_gm = GM.fit_predict(X)

plt.figure()
plt.title('Gaussian Mixture')
for i in range(2):
  plt.scatter(X[y_gm == i][:, 0], X[y_gm == i][:, 1], c = colors_list2[i])
########################################

########## Your answer here ############
# OPTICS...
optics = OPTICS(min_samples = 5)

y_optics = optics.fit_predict(X)

plt.figure()
plt.title('OPTICS')
for i in range(2):
  plt.scatter(X[y_optics == i][:, 0], X[y_optics == i][:, 1], c = colors_list2[i])
########################################
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
# Reapply all these different clustering methods to another new dataset. 
# Here we are using make_blobs. Refer to this link: 
# https://scikit-learn.org/stable/modules/generated/sklearn.datasets.make_blobs.html

############## Given code ##############
from sklearn import datasets
import numpy as np
X, y = datasets.make_blobs(n_samples=100, random_state=3)
transformation = [[0.6, -0.6], [-0.4, 0.8]]
X = np.dot(X, transformation)
########################################

########## Your answer here ############
# KMeans...
kmeans = KMeans(n_clusters = 3, random_state = 42)

kmeans.fit(X)
y_kmeans = kmeans.predict(X)

plt.figure()
plt.title('K-Means')
for i in range(3):
  plt.scatter(X[y_kmeans == i][:, 0], X[y_kmeans == i][:, 1], c = colors_list[i])
########################################


########## Your answer here ############
# SpectralClustering... 
spec = SpectralClustering(n_clusters = 3, n_components = 3)

y_spec = spec.fit_predict(X)

plt.figure()
plt.title('Spectral Clustering')
for i in range(3):
  plt.scatter(X[y_spec == i][:, 0], X[y_spec == i][:, 1], c = colors_list[i])
########################################


########## Your answer here ############
# GaussianMixture...
GM = GaussianMixture(n_components = 3, random_state = 42)

y_gm = GM.fit_predict(X)

plt.figure()
plt.title('Gaussian Mixture')
for i in range(3):
  plt.scatter(X[y_gm == i][:, 0], X[y_gm == i][:, 1], c = colors_list[i])
########################################

########## Your answer here ############
# OPTICS...
optics = OPTICS(min_samples = 15)

y_optics = optics.fit_predict(X)

plt.figure()
plt.title('OPTICS')
for i in range(3):
  plt.scatter(X[y_optics == i][:, 0], X[y_optics == i][:, 1], c = colors_list[i])
########################################
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %% [markdown]
# ### Problem 4
# Now, we are going to try different hierarchical clustering. Refer to this link for more information: https://scikit-learn.org/stable/modules/generated/sklearn.cluster.AgglomerativeClustering.html.

# %%
############## Given code ##############
X,y = datasets.make_circles(200)
from sklearn.cluster import AgglomerativeClustering
cluster = AgglomerativeClustering(n_clusters=2, linkage='ward') # change the min_samples to see different clustering results
########################################

########## Your answer here ############
labels = cluster.fit_predict(X)

plt.figure()
plt.title('Ward Linkage')
for i in range(2):
  plt.scatter(X[labels == i][:, 0], X[labels == i][:, 1], c = colors_list2[i])
########################################

############## Given code ##############
from sklearn.cluster import AgglomerativeClustering
cluster = AgglomerativeClustering(n_clusters=2, linkage='complete') # change the min_samples to see different clustering results
########################################

########## Your answer here ############
labels = cluster.fit_predict(X)

plt.figure()
plt.title('Complete Linkage')
for i in range(2):
  plt.scatter(X[labels == i][:, 0], X[labels == i][:, 1], c = colors_list2[i])
########################################

############## Given code ##############
from sklearn.cluster import AgglomerativeClustering
cluster = AgglomerativeClustering(n_clusters=2, linkage='average') # change the min_samples to see different clustering results
########################################

########## Your answer here ############
labels = cluster.fit_predict(X)

plt.figure()
plt.title('Average Linkage')
for i in range(2):
  plt.scatter(X[labels == i][:, 0], X[labels == i][:, 1], c = colors_list2[i])
########################################

############## Given code ##############
from sklearn.cluster import AgglomerativeClustering
cluster = AgglomerativeClustering(n_clusters=2, linkage='single') # change the min_samples to see different clustering results
########################################

########## Your answer here ############
labels = cluster.fit_predict(X)

plt.figure()
plt.title('Single Linkage')
for i in range(2):
  plt.scatter(X[labels == i][:, 0], X[labels == i][:, 1], c = colors_list2[i])
########################################
